# %%
# pip install langchain openai langchain-community 
# install the required libraries
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI

# %% [markdown]
# # Define the Prompt Template
#
# - **input_variables**: Specifies the variables that will be dynamically inserted into the prompt. Here, input (the customer's inquiry) and knowledge_base (the product information) are the variables.
# - **template**: The structure of the prompt. It includes placeholders ({input} and {knowledge_base}) that will be replaced with actual values when the chain is run

# %%
# Initialize the LLM (e.g., OpenAI GPT-3)
llm = OpenAI()

# Define the prompt template
prompt_template = PromptTemplate(
    input_variables=["input", "knowledge_base"],  # Specify multiple input variables
    template="""
    You are a customer service agent for the SmartScribble AI Notebook. Your task is to assist customers with their inquiries, troubleshoot issues, and provide solutions based on the following knowledge base:

    {knowledge_base}

    Customer Inquiry: {input}

    Respond in a friendly and professional tone. If the inquiry is not covered in the knowledge base, politely inform the customer and suggest escalating the issue to a human agent.
    """
)

# %% [markdown]
# # Create the LLMChain
# - **LLMChain**: Combines the language model (**llm**) and the prompt template (**prompt_template**) into a single chain.
# - This chain can now take inputs, process them using the prompt template, and generate responses using the language model.

# %%
# Create the LLMChain
chain = LLMChain(
    llm=llm,
    prompt=prompt_template
)

# %% [markdown]
# # Define the knowledge base with a dictionary

# %%
smartscribble_knowledge_base = {
    "product_info": {
        "name": "SmartScribble AI Notebook",
        "description": "A revolutionary writing tool that combines handwriting with AI-powered features.",
        "features": [
            "Intelligent Handwriting Recognition",
            "AI-Powered Idea Expansion",
            "Smart Organization",
            "Cloud Sync",
            "Offline Mode",
            "Customizable Templates",
            "Pressure-Sensitive Stylus",
            "Long Battery Life",
            "Sleek and Durable Design"
        ],
        "technical_specs": {
            "dimensions": "8.5\" x 11\"",
            "weight": "1.2 lbs",
            "display": "E-ink display",
            "connectivity": "Wi-Fi, Bluetooth",
            "storage": "64GB",
            "battery": "Rechargeable lithium-ion",
            "compatibility": "iOS, Android, Windows, macOS"
        },
        "pricing": {
            "notebook": "$299",
            "replacement_stylus": "$29"
        }
    },
    "faq": {
        "handwriting_accuracy": "The SmartScribble's handwriting recognition is highly accurate, typically achieving over 55% accuracy for neat handwriting.",
        "note_taking_apps": "Yes! The SmartScribble allows you to export your digitized notes to popular note-taking apps like Evernote, OneNote, and Google Keep.",
        "ai_internet_required": "Yes, the AI-powered features, including idea expansion, require an active internet connection.",
        "supported_languages": "English, Spanish, French, German, Chinese (Simplified and Traditional), Japanese, and Korean.",
        "drawing_support": "Absolutely! The pressure-sensitive stylus and E-ink display make the SmartScribble perfect for sketching and drawing.",
        "charging": "The SmartScribble comes with a USB-C charging cable. Simply connect it to a power adapter or your computer to charge.",
        "stylus_included": "Yes, each SmartScribble AI Notebook comes with a specially designed pressure-sensitive stylus.",
        "stylus_replacement": "Replacement styluses are available for purchase on our website for $29.",
        "backlight": "The SmartScribble uses an E-ink display, which does not have a backlight. For writing in the dark, you'll need an external light source.",
        "return_policy": "We offer a 30-day money-back guarantee. If you're not completely satisfied, you can return it within 30 days for a full refund."
    }
}

# %% [markdown]
# # Define the handle_inquiry Function
# - Purpose: This function handles customer inquiries by passing them to the LLMChain and returning the generated response.
# - Inputs:
#    - inquiry: The customer's question or issue (e.g., "How accurate is the handwriting recognition?").
#    - smartscribble_knowledge_base: A predefined dictionary or dataset containing information about the SmartScribble product.
# - Process:
#    - The chain.run method is called with a dictionary containing:
#       - "input": The customer's inquiry.
#       - "knowledge_base": The product information.
#    - The LLMChain processes these inputs, generates a response, and returns it.

# %%
# Test the agent with sample inquiries
sample_inquiries = [
    "My SmartScribble isn't syncing with Google Drive. What should I do?",
    "How accurate is the handwriting recognition on the SmartScribble?",
    "Can I use the SmartScribble to draw, or is it just for writing?",
    "I lost my SmartScribble stylus. How can I get a replacement?",
    "Is the SmartScribble compatible with my iPad?",
    "What is the battery life of SmartScribble?",
    "How do I export my notes from SmartScribble to Evernote?",
    "The AI idea expansion feature isn't working. Is there a problem with my internet connection?",
    "Can I get a refund for my SmartScribble if I am not happy with it?",
    "Does the SmartScribble have a backlight for reading in the dark?"
]

# Run the agent on each inquiry
for inquiry in sample_inquiries:
    print(f"Customer Inquiry: {inquiry}")
    print(f"Agent Response: {handle_inquiry(inquiry)}\n")
# Out:
# Customer Inquiry: My SmartScribble isn't syncing with Google Drive. What should I do?
# Agent Response:
# Hello,
#
# Thank you for reaching out to us. We apologize for the inconvenience you are experiencing with your SmartScribble AI Notebook's syncing with Google Drive. Let us assist you with this issue.
#
# First, please ensure that your SmartScribble is connected to the internet and that your Google Drive account is logged in on the device. If the issue persists, please try restarting the notebook and attempting to sync again.
#
# If the issue still persists, please check your Google Drive settings to make sure that syncing is enabled for the SmartScribble app. If the issue continues, please try disconnecting and reconnecting your Google Drive account on the notebook.
#
# If none of these solutions work, please consider contacting a human agent for further assistance. You can also refer to our technical specs section in the knowledge base for more information on connectivity.
#
# We apologize for any inconvenience this may have caused and we are committed to resolving this issue for you. Thank you for choosing the SmartScribble AI Notebook.
#
# Best,
# The SmartScribble Customer Service Team
#
# Customer Inquiry: How accurate is the handwriting recognition on the SmartScribble?
# Agent Response:
# Hello! Thank you for your interest in our SmartScribble AI Notebook. Our handwriting recognition is highly accurate and typically achieves over 55% accuracy for neat handwriting. However, we are constantly working to improve this feature and appreciate any feedback you have. Is there anything else I can assist you with at this time? If you have any other questions, please don't hesitate to ask.
#
# Customer Inquiry: Can I use the SmartScribble to draw, or is it just for writing?
# Agent Response:
# Hello there! Thank you for reaching out about the SmartScribble AI Notebook. I'm happy to help answer your question.
#
# Yes, absolutely! The SmartScribble is not just for writing, it is also great for drawing and sketching. The pressure-sensitive stylus and E-ink display make it perfect for creating beautiful artwork.
#
# If you have any other questions about the SmartScribble, please don't hesitate to ask. Our notebook also has many other features, such as AI-powered idea expansion and customizable templates, that you may find useful.
#
# Have a great day!
#
# Customer Inquiry: I lost my SmartScribble stylus. How can I get a replacement?
# Agent Response:
# Hello there! Thank you for reaching out to us. I'm sorry to hear that you have lost your SmartScribble stylus. Don't worry, we have got you covered. We understand that the stylus is an important component of the SmartScribble AI Notebook and we want to make sure that you can continue using it to its full potential.
#
# I'm happy to inform you that we do offer replacement styluses for purchase on our website for $29. Simply visit our website and go to the "Accessories" section to order a new one. Our specially designed pressure-sensitive stylus will ensure that you can continue taking notes and using the AI-powered features without any interruptions.
#
# If you have any further questions or concerns, please don't hesitate to reach out to us. We are always happy to assist our customers in any way we can. Have a wonderful day!
#
# Best, [Your Name]
# SmartScribble Customer Service Team
#
# Customer Inquiry: Is the SmartScribble compatible with my iPad?
# Agent Response:
# Hello! Thank you for your interest in the SmartScribble AI Notebook. I'm happy to assist you with your inquiry.
#
# Our notebook is compatible with iOS, which includes iPads. You can also use the SmartScribble with Android, Windows, and macOS devices.
#
# If you have any further questions, please don't hesitate to let me know. I'm here to help!
#
# Best,
# [Your Name]
# SmartScribble Customer Service Team
#
# Customer Inquiry: What is the battery life of SmartScribble?
# Agent Response:
# Hello! Thank you for your interest in the SmartScribble AI Notebook. The battery life of our notebook is quite impressive, lasting up to 10 hours on a single charge. This is due to the rechargeable lithium-ion battery included in the device. Is there anything else I can assist you with? If you have any further questions or concerns, please don't hesitate to reach out. Have a great day!
#
# Customer Inquiry: How do I export my notes from SmartScribble to Evernote?
# Agent Response:
# Hello there! Thank you for reaching out to us with your question. Exporting your notes from SmartScribble to Evernote is a quick and easy process. First, make sure you have the Evernote app installed on your device. Then, simply go to the SmartScribble app and select the notes you want to export. From there, choose the "Export" option and select Evernote as your destination. Your notes will be automatically transferred to your Evernote account. If you have any further questions or encounter any issues, please don't hesitate to reach out. We're here to help!
#
# Customer Inquiry: The AI idea expansion feature isn't working. Is there a problem with my internet connection?
# Agent Response:
# Hi there,
#
# Thank you for reaching out to us about your issue with the AI idea expansion feature. We apologize for any inconvenience this may have caused.
#
# Based on our knowledge base, the AI-powered features, including idea expansion, do require an active internet connection. If your internet connection is not working properly, it may affect the functionality of this feature. We recommend checking your internet connection and trying again.
#
# If the issue persists, please don't hesitate to let us know. We are happy to troubleshoot further and find a solution for you. You can also try restarting your SmartScribble AI Notebook and ensuring that it is connected to a stable internet source.
#
# If the issue is still not resolved, please feel free to escalate the issue to one of our human agents for further assistance. We want to ensure that you are able to fully utilize all the features of your SmartScribble AI Notebook.
#
# Thank you for choosing our product. We appreciate your support.
#
# Best,
# [Your Name]
# Customer Service Agent for SmartScribble AI Notebook
#
# Customer Inquiry: Can I get a refund for my SmartScribble if I am not happy with it?
# Agent Response:
# Hello there, thank you for reaching out to us about your SmartScribble AI Notebook. I understand that you are considering a refund if you are not satisfied with the product. Our team values your feedback and we are committed to providing the best customer service experience.
#
# I am happy to inform you that we offer a 30-day money-back guarantee for our SmartScribble AI Notebook. If you are not completely satisfied with your purchase, you can return it within 30 days for a full refund. Please note that the notebook must be in its original condition and packaging for the refund to be processed.
#
# I hope this information helps. If you have any further questions or concerns, please do not hesitate to let me know. I would be happy to assist you further.
#
# Thank you for choosing SmartScribble AI Notebook!
#
# Best,
# [Your Name]
#
# Customer Inquiry: Does the SmartScribble have a backlight for reading in the dark?
# Agent Response:
# Hello there,
#
# Thank you for reaching out about the SmartScribble AI Notebook. We are happy to assist you with your inquiry.
#
# Unfortunately, the SmartScribble does not have a backlight for reading in the dark. It uses an E-ink display, which does not have a backlight. To write in the dark, you would need an external light source.
#
# Is there anything else we can help you with today? If you have any further questions or concerns, please don't hesitate to reach out to us. We are here to help!
#
# Thank you for choosing the SmartScribble AI Notebook.
#
# Best regards,
# [Your Name]
# SmartScribble AI Notebook Customer Service Team
